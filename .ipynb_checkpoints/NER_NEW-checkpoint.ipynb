# %% [markdown]
# # NAMED ENTITY RECOGNITION USING BI-LSTM

# %% [markdown]
# ### IMPORTING LIBRARIES:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### IMPORTING DATA:

# %%
data = pd.read_csv('new_ner.csv', encoding = 'latin1')
data.fillna(method = 'ffill', inplace = True)
data.head().append(data.tail())
# Out:
#               Sentence #           Word  POS Tag
# 0            Sentence: 1      Thousands  NNS   O
# 1            Sentence: 1             of   IN   O
# 2            Sentence: 1  demonstrators  NNS   O
# 3            Sentence: 1           have  VBP   O
# 4            Sentence: 1        marched  VBN   O
# 1048570  Sentence: 47959           they  PRP   O
# 1048571  Sentence: 47959      responded  VBD   O
# 1048572  Sentence: 47959             to   TO   O
# 1048573  Sentence: 47959            the   DT   O
# 1048574  Sentence: 47959         attack   NN   O

# %%
data.shape
# Out:
# (1048575, 4)

# %%
data.drop(['POS'], axis = 1, inplace = True)

# %%
print(f'No.of Unique Words:{data.Word.nunique()}')
print(f'No.of Unique Tags:{data.Tag.nunique()}')
# Out:
# No.of Unique Words:35178
# No.of Unique Tags:17

# %%
plt.figure(figsize = (10, 5))
plt.style.use('seaborn')
plt.hist(data.Tag, log = True, bins = 40, label = 'Tags', color = 'red')
plt.title('UNIQUE TAGS', fontsize = 13)
plt.xlabel('TAGS', fontsize = 13)
plt.ylabel('COUNT', fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ### GROUPING WORDS AND TAGS:

# %%
words = list(set(data['Word'].values))
num_words = len(words)
tags = list(set(data['Tag'].values))
n_tags = len(tags)
print(num_words, n_tags)
# Out:
# 35178 17

# %%
class Grouping:
    
    def __init__(self, data):
        self.data = data
        self.empty = False
        agg_fun = lambda S : [(w, t) for w, t in zip(S['Word'].values.tolist(),
                                                     S['Tag'].values.tolist())]
        self.group = self.data.groupby('Sentence #').apply(agg_fun)
        self.sentence = [sen for sen in self.group]

# %%
getter = Grouping(data)
sentences = getter.sentence

# %%
sentences[0]
# Out:
# [('Thousands', 'O'),
#  ('of', 'O'),
#  ('demonstrators', 'O'),
#  ('have', 'O'),
#  ('marched', 'O'),
#  ('through', 'O'),
#  ('London', 'B-geo'),
#  ('to', 'O'),
#  ('protest', 'O'),
#  ('the', 'O'),
#  ('war', 'O'),
#  ('in', 'O'),
#  ('Iraq', 'B-geo'),
#  ('and', 'O'),
#  ('demand', 'O'),
#  ('the', 'O'),
#  ('withdrawal', 'O'),
#  ('of', 'O'),
#  ('British', 'B-gpe'),
#  ('troops', 'O'),
#  ('from', 'O'),
#  ('that', 'O'),
#  ('country', 'O'),
#  ('.', 'O')]

# %% [markdown]
# ### MAPPING WORDS AND TAGS TO INDEX:

# %%
word2idx = {w : i + 1 for i, w in enumerate(words)}
tag2idx = {t : i for i, t in enumerate(tags)}

# %%
word2idx
# Out:
# {'Apollo': 1,
#  'casts': 2,
#  'Koichi': 3,
#  'astrology': 4,
#  'tolled': 5,
#  'bazaar': 6,
#  'Ohio': 7,
#  'contradicted': 8,
#  'tribespeople': 9,
#  'drafting': 10,
#  'Wesley': 11,
#  'Wooden': 12,
#  'vaccine': 13,
#  'launched': 14,
#  'U.S.-Venezuelan': 15,
#  'Then': 16,
#  'Belgian': 17,
#  'Daylam': 18,
#  'Lago': 19,
#  'tax-relief': 20,
#  '31-30': 21,
#  'Boluk': 22,
#  'al-Dagma': 23,
#  'qualifications': 24,
#  'Canaries': 25,
#  'Radcliffe': 26,
#  'seen': 27,
#  'institution': 28,
#  'classification': 29,
#  'Gilad': 30,
#  'goals': 31,
#  'Certain': 32,
#  'five-month-long': 33,
#  'Gheorghe': 34,
#  'close-ally': 35,
#  'joy': 36,
#  'Ramazan': 37,
#  'wheat': 38,
#  'Eyewitnesses': 39,
#  'Hargeisa': 40,
#  'spam': 41,
#  'dishes': 42,
#  'raids': 43,
#  'Kamuzu': 44,
#  're-stating': 45,
#  'customs': 46,
#  'Curry': 47,
#  'singer-songwriter': 48,
#  'George': 49,
#  'accompanying': 50,
#  'melt': 51,
#  'rejection': 52,
#  'motorist': 53,
#  '5,52,300': 54,
#  'spotted': 55,
#  'Dell': 56,
#  'Albade': 57,
#  'seeks': 58,
#  'Explosive': 59,
#  'literacy': 60,
#  'Martinho': 61,
#  'Tutor': 62,
#  '5-million': 63,
#  'Talansky': 64,
#  'public-opinion': 65,
#  'interrogated': 66,
#  'world-wide': 67,
#  'coal-fired': 68,
#  'Mekdad': 69,
#  'distracted': 70,
#  'enemies': 71,
#  'Sughayr': 72,
#  'Civic': 73,
#  'Philippoussis': 74,
#  'Jusoh': 75,
#  'Norodom': 76,
#  'multi-million-selling': 77,
#  'Cormac': 78,
#  'Gijs': 79,
#  'yoke': 80,
#  'chapel': 81,
#  'two-and-a-half-year': 82,
#  'Central': 83,
#  'pled': 84,
#  'Metropolitan': 85,
#  'variant': 86,
#  'Rowhani': 87,
#  '74': 88,
#  'government': 89,
#  'manifesto': 90,
#  'surgeon': 91,
#  'Haradinaj': 92,
#  'horseback': 93,
#  '30-year-old': 94,
#  'enticed': 95,
#  'sowing': 96,
#  'Talal': 97,
#  '4.3': 98,
#  'splinter': 99,
#  'fractures': 100,
#  'shore': 101,
#  'Nadhem': 102,
#  'crafted': 103,
#  'Vicente': 104,
#  'Napier': 105,
#  'duck': 106,
#  'nearby': 107,
#  'Pinter': 108,
#  'shipyards': 109,
#  'elderly': 110,
#  'Shengyou': 111,
#  'thorough': 112,
#  '1841': 113,
#  'Video': 114,
#  '30,000': 115,
#  'Marriott': 116,
#  'Eden': 117,
#  'install': 118,
#  'violators': 119,
#  'Dal': 120,
#  'Satterfield': 121,
#  'Survivors': 122,
#  'submerged': 123,
#  'gemstones': 124,
#  'ninth-century': 125,
#  'Shiv': 126,
#  'Corruption': 127,
#  'cigarettes': 128,
#  'short-wave': 129,
#  'Unfortunately': 130,
#  'Tanzania-based': 131,
#  'Denver': 132,
#  '11th': 133,
#  'optician': 134,
#  'Ntini': 135,
#  'Raikkonen': 136,
#  'staffing': 137,
#  'Join': 138,
#  'tries': 139,
#  'law-and-order': 140,
#  'el-Bared': 141,
#  'providers': 142,
#  'Rignot': 143,
#  'Mercantile': 144,
#  'solutions': 145,
#  'sprinters': 146,
#  'lakeside': 147,
#  'sadly': 148,
#  'Minya': 149,
#  'broadcasts': 150,
#  'prevent': 151,
#  'Delphi': 152,
#  'firefights': 153,
#  'non-lethal': 154,
#  'Michiko': 155,
#  'cutbacks': 156,
#  'Astronauts': 157,
#  'inflamed': 158,
#  'nominee': 159,
#  '130.6': 160,
#  'PSV': 161,
#  'Oezil': 162,
#  '1901': 163,
#  'assented': 164,
#  'photographers': 165,
#  'Potential': 166,
#  'Hostess': 167,
#  'McBride': 168,
#  'distinctive': 169,
#  'bay': 170,
#  'land': 171,
#  'al-Momen': 172,
#  'Eve': 173,
#  'Sarath': 174,
#  'Care': 175,
#  'Nasab': 176,
#  'avocados': 177,
#  'custody': 178,
#  'showings': 179,
#  'Macedonian-American': 180,
#  'mockery': 181,
#  'Cindy': 182,
#  'Indians': 183,
#  'should': 184,
#  'Garhi': 185,
#  '9.5': 186,
#  'Zetas': 187,
#  'income': 188,
#  'scarce': 189,
#  'CAMARA': 190,
#  'floor': 191,
#  'Center-left': 192,
#  'evangelization': 193,
#  'seawater': 194,
#  'contrive': 195,
#  'surgical': 196,
#  'Wolf': 197,
#  'Pierce': 198,
#  'large-caliber': 199,
#  'delighted': 200,
#  'Souq': 201,
#  'noting': 202,
#  'Amy': 203,
#  'Selected': 204,
#  'trampled': 205,
#  'Reformist': 206,
#  'bag': 207,
#  'clause': 208,
#  'cooled': 209,
#  'occupants': 210,
#  'Kravchenko': 211,
#  'Dialogue': 212,
#  'plume': 213,
#  'robberies': 214,
#  'automated': 215,
#  'Chile': 216,
#  'Polio': 217,
#  'bury': 218,
#  'unnerve': 219,
#  'Vives': 220,
#  'Indian-administered': 221,
#  'Santander': 222,
#  'Ugandans': 223,
#  'Yugansk': 224,
#  "d'Urgell": 225,
#  'Empires': 226,
#  'Muhsin': 227,
#  'Jamuna': 228,
#  'filmmaking': 229,
#  'journals': 230,
#  'Airtour': 231,
#  'demonstrations': 232,
#  '1990': 233,
#  'ensures': 234,
#  'once-bitter': 235,
#  'travelling': 236,
#  '28th': 237,
#  'GONDWE': 238,
#  'ozone': 239,
#  '70.85': 240,
#  'occasional': 241,
#  'sea': 242,
#  'destinations': 243,
#  'Jibla': 244,
#  'Kristofferson': 245,
#  'immoral': 246,
#  'Booth': 247,
#  'sir': 248,
#  'rocketed': 249,
#  'tense': 250,
#  'blackboard': 251,
#  'shelled': 252,
#  'Timberlake': 253,
#  'Subur': 254,
#  'Wanthana': 255,
#  'Hualan': 256,
#  'Non-Violent': 257,
#  'MILF': 258,
#  'Rashid': 259,
#  'examining': 260,
#  'fugitive': 261,
#  'Spider': 262,
#  'profits': 263,
#  'attorney-general': 264,
#  'Isolated': 265,
#  'Sipah-e-Sahaba': 266,
#  'resigns': 267,
#  'moves': 268,
#  'Apure': 269,
#  'Fyodor': 270,
#  'Kiteswere': 271,
#  'leaks': 272,
#  'Chacahua': 273,
#  'untaxed': 274,
#  '1.329': 275,
#  'breakthroughs': 276,
#  'Harriet': 277,
#  'quake-hit': 278,
#  'Sasa': 279,
#  'descending': 280,
#  'Grenoble': 281,
#  'Heinonen': 282,
#  'cite': 283,
#  '747-8': 284,
#  'columnist': 285,
#  'outsold': 286,
#  'beatified': 287,
#  'Qureia': 288,
#  'favoritism': 289,
#  'Naftogaz': 290,
#  'Encouragement': 291,
#  'pit': 292,
#  'Son': 293,
#  'sedentary': 294,
#  'Task': 295,
#  'operators': 296,
#  'vitamin': 297,
#  'religion': 298,
#  'Tutsi': 299,
#  'persist': 300,
#  'Namgyel': 301,
#  'Maoists': 302,
#  'atom': 303,
#  'unbeatable': 304,
#  'Guerraas': 305,
#  'SOGLO': 306,
#  'Interceptor': 307,
#  'aspiring': 308,
#  'VE': 309,
#  'assessments': 310,
#  'Envoys': 311,
#  'ai': 312,
#  'mi': 313,
#  'Hassanpour': 314,
#  'Lashkar-e-Toiba': 315,
#  'super-G': 316,
#  'hijack': 317,
#  '4,00,000': 318,
#  'Moussaoui': 319,
#  'Erkki': 320,
#  'Kihonge': 321,
#  'heightened': 322,
#  'Teikoku': 323,
#  'contracts': 324,
#  'Providencia': 325,
#  'cancelation': 326,
#  'orange': 327,
#  'ratification': 328,
#  'interviewed': 329,
#  'NYYAZOW': 330,
#  'sanction': 331,
#  'teachers': 332,
#  'deliveries': 333,
#  'tankers': 334,
#  'Taormina': 335,
#  'XII': 336,
#  'Meridian': 337,
#  'Garrigues': 338,
#  'suppliers': 339,
#  'BOLIVAR': 340,
#  'incorporated': 341,
#  'presidential': 342,
#  'Monsanto': 343,
#  '1994': 344,
#  'flying': 345,
#  'nutrition': 346,
#  'Fabian': 347,
#  'Corpus': 348,
#  'ANP': 349,
#  'Street': 350,
#  'perspective': 351,
#  'side': 352,
#  'cardiovascular': 353,
#  'risks': 354,
#  'insured': 355,
#  'Meuli': 356,
#  'Qaratun': 357,
#  'Redline': 358,
#  'discharged': 359,
#  'expensive': 360,
#  'grain-field': 361,
#  'disturbed': 362,
#  'Snake': 363,
#  'arisen': 364,
#  'Jewish': 365,
#  'Enming': 366,
#  'Patriotic': 367,
#  'Tenzin': 368,
#  'riot': 369,
#  'kick': 370,
#  'fuselage': 371,
#  'publicly': 372,
#  'all-around': 373,
#  'down': 374,
#  'Bear': 375,
#  'frigid': 376,
#  'visa': 377,
#  'pilot': 378,
#  'Ein': 379,
#  'Si': 380,
#  'France-Albert': 381,
#  'non-government': 382,
#  '3.76': 383,
#  'marathoner': 384,
#  'Mar': 385,
#  'Comparing': 386,
#  'Ashwell': 387,
#  'Coca-Cola': 388,
#  'Housing': 389,
#  'Villagers': 390,
#  'coconut': 391,
#  'titled': 392,
#  'underscore': 393,
#  'proteins': 394,
#  'vehicles': 395,
#  '29th': 396,
#  'Mukhtaran': 397,
#  'biologist': 398,
#  'technological': 399,
#  'lookout': 400,
#  '163-seat': 401,
#  'shrank': 402,
#  'Whoopie': 403,
#  'did': 404,
#  'Fuad': 405,
#  'Gibran': 406,
#  '7,000': 407,
#  'Toufik': 408,
#  '22.772': 409,
#  'kings': 410,
#  'insurgency-hit': 411,
#  'combative': 412,
#  '30-day': 413,
#  'Shops': 414,
#  'disapproves': 415,
#  'Martti': 416,
#  'Universidad': 417,
#  'Nanking': 418,
#  'Album': 419,
#  'developmentaly-oriented': 420,
#  'ingratitude': 421,
#  'Moun': 422,
#  'steep': 423,
#  'three-million': 424,
#  'princes': 425,
#  'Syed': 426,
#  'Senators': 427,
#  'pork': 428,
#  "Shi'ite-led": 429,
#  'Jamaican': 430,
#  'refine': 431,
#  'earthen': 432,
#  'cardio-circulatory': 433,
#  'whose': 434,
#  'issues': 435,
#  'stamps': 436,
#  'environmentalists': 437,
#  'topped': 438,
#  'Rescue': 439,
#  'Date': 440,
#  'Challenger': 441,
#  'Stanizai': 442,
#  'Crisis': 443,
#  'Kazakhs': 444,
#  'rustling': 445,
#  'Vorotan': 446,
#  'Israeli-Palestinian': 447,
#  'Blige': 448,
#  'tub': 449,
#  'Costner': 450,
#  'source': 451,
#  'Tobago': 452,
#  'Sayyaf': 453,
#  'depend': 454,
#  'Worker': 455,
#  'Mazar-e-Sharif': 456,
#  'repeal': 457,
#  'terrible': 458,
#  'freedom': 459,
#  'controversial': 460,
#  'challenge': 461,
#  'literature': 462,
#  '81-4': 463,
#  'repay': 464,
#  'dormant': 465,
#  'ignited': 466,
#  'crusade': 467,
#  'Nasa': 468,
#  '0.8': 469,
#  '146': 470,
#  'condemn': 471,
#  'perceiving': 472,
#  'mingling': 473,
#  'al-Aqili': 474,
#  'Gold': 475,
#  'settler': 476,
#  'preachers': 477,
#  'Irish': 478,
#  'River': 479,
#  'Kuznetsov': 480,
#  'Solana': 481,
#  'Raipur': 482,
#  'Jiangxi': 483,
#  'streaming': 484,
#  'midst': 485,
#  'Regiment': 486,
#  'armies': 487,
#  'Karroubi': 488,
#  'spends': 489,
#  'S.': 490,
#  '250': 491,
#  'households': 492,
#  'Bougainville': 493,
#  'cheap': 494,
#  'sleet': 495,
#  'attache': 496,
#  'truck': 497,
#  'precious': 498,
#  'Naseem': 499,
#  'professional': 500,
#  'Boundary': 501,
#  'black-clad': 502,
#  'embankments': 503,
#  'cholera': 504,
#  'free': 505,
#  'discusses': 506,
#  'Venezuela-based': 507,
#  'trucking': 508,
#  'header': 509,
#  'Washington-area': 510,
#  'solicited': 511,
#  '4,200': 512,
#  'Fillon': 513,
#  'Bechuanaland': 514,
#  'Baume': 515,
#  'quantities': 516,
#  'cone': 517,
#  'recouped': 518,
#  'Mala': 519,
#  'ONCE': 520,
#  'adamant': 521,
#  'payloads': 522,
#  'accompany': 523,
#  'courageous': 524,
#  'stuff': 525,
#  'maimed': 526,
#  'dinners': 527,
#  'reinsurer': 528,
#  'tune': 529,
#  'Courtney': 530,
#  'hypothermia': 531,
#  'mate': 532,
#  'arabic': 533,
#  'onerous': 534,
#  'Cameraman': 535,
#  'taxi': 536,
#  'burn': 537,
#  'weathered': 538,
#  'Barakin': 539,
#  'NATO-EU': 540,
#  'Tian': 541,
#  'supporters': 542,
#  'Skeleton': 543,
#  'evaluate': 544,
#  'champ': 545,
#  'States': 546,
#  'Lustiger': 547,
#  'concocted': 548,
#  'film': 549,
#  'near-by': 550,
#  'Republican-controlled': 551,
#  'European-owned': 552,
#  'Saqiz': 553,
#  'inclusive': 554,
#  'Waldron': 555,
#  '5.5': 556,
#  'above-market': 557,
#  'Jensen': 558,
#  'Ahead': 559,
#  'edition': 560,
#  '52-week': 561,
#  'compliments': 562,
#  'saves': 563,
#  'Filmyard': 564,
#  'reining': 565,
#  'underlined': 566,
#  'expanding': 567,
#  'clampdown': 568,
#  '1.06': 569,
#  'Merle': 570,
#  'Carriles': 571,
#  '336': 572,
#  'Maskhadov': 573,
#  'high-seas': 574,
#  'Walheim': 575,
#  'Ana': 576,
#  'Iraqi-led': 577,
#  'match-fixing': 578,
#  'shopping': 579,
#  'militant': 580,
#  'Redskins': 581,
#  'deceptive': 582,
#  '19.7': 583,
#  'disappearing': 584,
#  'Silesia': 585,
#  'tolerant': 586,
#  'Noguchi': 587,
#  'infromation': 588,
#  'Deutchmark': 589,
#  'Tharanga': 590,
#  'nasty': 591,
#  'author': 592,
#  'Abdullah': 593,
#  'Rowsch': 594,
#  'gag': 595,
#  'Soglo': 596,
#  'Al-Ghoul': 597,
#  'obsessed': 598,
#  'dire': 599,
#  'Amezcua': 600,
#  'Antioquia': 601,
#  'fedora-wearing': 602,
#  'middleman': 603,
#  'Math': 604,
#  'husbands': 605,
#  'principalities': 606,
#  'violations': 607,
#  'open-market': 608,
#  'stay-order': 609,
#  'Victor': 610,
#  '2025': 611,
#  "d'": 612,
#  'Rights': 613,
#  'exclusive': 614,
#  'Correa': 615,
#  '53-minute': 616,
#  'Axis': 617,
#  '84-year-old': 618,
#  'commuter': 619,
#  'Neth': 620,
#  'Yeu-Tzuoo': 621,
#  'Mathew': 622,
#  'Cheyenne': 623,
#  'Khalid': 624,
#  'deciphering': 625,
#  'speeding': 626,
#  'acres': 627,
#  'Prevention': 628,
#  'tainting': 629,
#  'ailments': 630,
#  '33.5': 631,
#  '267': 632,
#  'reverses': 633,
#  'credible': 634,
#  'RCT': 635,
#  'Era': 636,
#  'possibility': 637,
#  'reconvene': 638,
#  'coordinates': 639,
#  'wiping': 640,
#  'Shahab-3': 641,
#  'capitalist': 642,
#  'Hares': 643,
#  'tragedy': 644,
#  'overland': 645,
#  'sentenced': 646,
#  'defeatism': 647,
#  'Humayun': 648,
#  'Milli': 649,
#  'Ran': 650,
#  'launches': 651,
#  'low-grade': 652,
#  'Kypriano': 653,
#  'melted': 654,
#  'Chee-hwa': 655,
#  'Wadowice': 656,
#  'marches': 657,
#  'solely': 658,
#  'already': 659,
#  'Predazzo': 660,
#  'suicide': 661,
#  'framework': 662,
#  'Russian-backed': 663,
#  'Tarique': 664,
#  '3,400-meter-high': 665,
#  'surfaces': 666,
#  'Gibraltar': 667,
#  'unchanged': 668,
#  'CBS': 669,
#  'stem': 670,
#  'overstaying': 671,
#  'IMB': 672,
#  'touchdowns': 673,
#  'VERY': 674,
#  'query': 675,
#  'whites': 676,
#  'View': 677,
#  '[': 678,
#  'al-Tikriti': 679,
#  'Nigerla': 680,
#  'faster': 681,
#  'circumcision': 682,
#  'confer': 683,
#  'candidacy': 684,
#  'uncertainties': 685,
#  'Oz': 686,
#  'hillsides': 687,
#  'greetings': 688,
#  'greenest': 689,
#  'Monteiro': 690,
#  'Bombers': 691,
#  'particular': 692,
#  'nabbed': 693,
#  'stores': 694,
#  'Giant': 695,
#  'Maharashtra': 696,
#  'Wenesday': 697,
#  'suitable': 698,
#  'sheep-and-cattle': 699,
#  'swelling': 700,
#  'amputation': 701,
#  'Al-Jazeera': 702,
#  'Opposition': 703,
#  'examiner': 704,
#  'generation': 705,
#  'Tzipi': 706,
#  'Chechen': 707,
#  'Belkadi': 708,
#  'Menoufia': 709,
#  'Ramdi': 710,
#  'enemy': 711,
#  'unhurt': 712,
#  'tract': 713,
#  'Kars-Akhalkalaki': 714,
#  'Muslim': 715,
#  'reversal': 716,
#  'Poupard': 717,
#  'Hema': 718,
#  'Dad': 719,
#  'seacoast': 720,
#  'doomsday': 721,
#  '32nd': 722,
#  'bleak': 723,
#  'kindergarten': 724,
#  'Basic': 725,
#  '49.8': 726,
#  'vowing': 727,
#  'analyze': 728,
#  'further': 729,
#  'Diaz': 730,
#  'output': 731,
#  'smothered': 732,
#  'C-130': 733,
#  'occurring': 734,
#  '1970': 735,
#  'batter': 736,
#  'second-highest': 737,
#  'precipitated': 738,
#  'notch': 739,
#  'Malaysian-led': 740,
#  'Realignment': 741,
#  '463': 742,
#  'Clay': 743,
#  'ABHISIT': 744,
#  'counseling': 745,
#  'shattered': 746,
#  'mitigated': 747,
#  'ICC': 748,
#  'Youssef': 749,
#  'Dunleavy': 750,
#  'dragged': 751,
#  'easterly': 752,
#  'Kansas': 753,
#  'qualify': 754,
#  'Israel': 755,
#  'spaghetti': 756,
#  'Tymoshenko': 757,
#  'Mudasir': 758,
#  'jolted': 759,
#  'Nevada': 760,
#  'Grammy': 761,
#  'Kariye': 762,
#  '11-day': 763,
#  'liberalizing': 764,
#  'crested': 765,
#  'eurozone': 766,
#  'years-long': 767,
#  'toy': 768,
#  'skidded': 769,
#  'affected': 770,
#  'inaction': 771,
#  'Faeldon': 772,
#  'Zaken': 773,
#  'Kasab': 774,
#  'unreported': 775,
#  'Vaccines': 776,
#  'break': 777,
#  'derivative': 778,
#  'vice': 779,
#  'Soul': 780,
#  '53.88': 781,
#  'small': 782,
#  'bankruptcy-law': 783,
#  'April': 784,
#  'drawing': 785,
#  'wide': 786,
#  'sprees': 787,
#  'four-sets': 788,
#  're-enactment': 789,
#  'Pronk': 790,
#  'institutionalizing': 791,
#  'Burma': 792,
#  'Boss': 793,
#  'suitors': 794,
#  'Express': 795,
#  'orientation': 796,
#  'regime': 797,
#  'nourished': 798,
#  '413': 799,
#  'showed': 800,
#  'feeling': 801,
#  'Libyan-owned': 802,
#  'Auwaerter': 803,
#  "al-Madai'ni": 804,
#  'Anambra': 805,
#  'Adrien': 806,
#  'Hangzhou': 807,
#  'line-up': 808,
#  'snowed': 809,
#  'Djalil': 810,
#  'H.I.V': 811,
#  'Thune': 812,
#  'victims': 813,
#  'Cordero': 814,
#  'Ghad': 815,
#  'congestion': 816,
#  'Radhia': 817,
#  'cough': 818,
#  'inoperable': 819,
#  'Loyal': 820,
#  'Chernobyl': 821,
#  'Sprat': 822,
#  'capitalized': 823,
#  '1939': 824,
#  'bribes-for-votes': 825,
#  'portfolio': 826,
#  'profitability': 827,
#  'persuade': 828,
#  'packaging': 829,
#  'mustard': 830,
#  'Thomas': 831,
#  'end': 832,
#  'Panjwayi': 833,
#  'prompt': 834,
#  'impassable': 835,
#  'Imports': 836,
#  'Shawkat': 837,
#  'undermines': 838,
#  'postpone': 839,
#  'illegitimate': 840,
#  'ran': 841,
#  'tipped': 842,
#  'Mexico-U.S.': 843,
#  'ca': 844,
#  'tongue': 845,
#  'calling': 846,
#  'Tattoo': 847,
#  'Kwajalein': 848,
#  'Sughd': 849,
#  'accidental': 850,
#  'Iscuande': 851,
#  'translates': 852,
#  'Blueberry': 853,
#  'Zeid': 854,
#  'Despite': 855,
#  'Ismail': 856,
#  '11-year': 857,
#  'examinations': 858,
#  'suffice': 859,
#  'Shopping': 860,
#  'observers': 861,
#  'Jebii': 862,
#  'Jaua': 863,
#  'spongiform': 864,
#  'Baidoa': 865,
#  'incite': 866,
#  'interwar': 867,
#  'mostly': 868,
#  'second-ranked': 869,
#  'entitlement': 870,
#  'Jean-Cyril': 871,
#  'SARS': 872,
#  'easy': 873,
#  'persecutors': 874,
#  'UkrGazEnergo': 875,
#  'Alberto': 876,
#  'Wakata': 877,
#  'component': 878,
#  'Body': 879,
#  'imposed': 880,
#  'West': 881,
#  'undergo': 882,
#  'pencil': 883,
#  'Dostum': 884,
#  'components': 885,
#  'Topol': 886,
#  'plunge': 887,
#  'renowed': 888,
#  'Altria': 889,
#  'unmanned': 890,
#  'overpopulation': 891,
#  'storm': 892,
#  'Marshall': 893,
#  'preserving': 894,
#  'Philadelphia': 895,
#  'disbanding': 896,
#  'Cuomo': 897,
#  'al-Harbi': 898,
#  'Peretz': 899,
#  'cash-strapped': 900,
#  'Sandanista': 901,
#  'Jarrin': 902,
#  'blackout': 903,
#  '86-year-old': 904,
#  'adjustment': 905,
#  'unopposed': 906,
#  'residing': 907,
#  'Lyons': 908,
#  'pitching': 909,
#  'Jalil': 910,
#  'Ties': 911,
#  'intervention': 912,
#  'Uruguay': 913,
#  'Tanweer': 914,
#  'Sitaula': 915,
#  'abused': 916,
#  'Kouk': 917,
#  '13.857': 918,
#  'read': 919,
#  'Khalaf': 920,
#  'WAEMU': 921,
#  '2.9': 922,
#  'al-Baghdadi': 923,
#  'length': 924,
#  'highways': 925,
#  'generals': 926,
#  'meteorological': 927,
#  '1,75,000': 928,
#  'love': 929,
#  'Guizhou': 930,
#  'phrase': 931,
#  'commemoration': 932,
#  'Susilo': 933,
#  'Dixie': 934,
#  'Narino': 935,
#  'unfortunately': 936,
#  'naysayers': 937,
#  '7,000-member': 938,
#  'pop': 939,
#  'laughable': 940,
#  'KITES': 941,
#  'stolen': 942,
#  'contingent': 943,
#  'Marcelo': 944,
#  'perfect': 945,
#  'confidential': 946,
#  'steel': 947,
#  'literally': 948,
#  'Theodor': 949,
#  'Abdul-Khalim': 950,
#  'roadway': 951,
#  'Cathedral': 952,
#  'Jansen': 953,
#  'referred': 954,
#  'whiskey': 955,
#  'dot': 956,
#  'unaffected': 957,
#  'ridicule': 958,
#  'test-fired': 959,
#  'Progressive': 960,
#  'pricing': 961,
#  'Ghalawiya': 962,
#  'Antarctica': 963,
#  'Uri': 964,
#  'fallback': 965,
#  'modeled': 966,
#  'skimming': 967,
#  'Sanctions': 968,
#  'decades-old': 969,
#  'Aweil': 970,
#  'Kai': 971,
#  'Mordechai': 972,
#  'housed': 973,
#  'reopened': 974,
#  'dormitories': 975,
#  'downed': 976,
#  'corruption-related': 977,
#  'ex-Prime': 978,
#  'site': 979,
#  'headfirst': 980,
#  'reclaimed': 981,
#  'Malay': 982,
#  'Pound': 983,
#  'Ezirouali': 984,
#  'assessors': 985,
#  'covertly': 986,
#  'best-selling': 987,
#  'Gerry': 988,
#  'compromised': 989,
#  'two-year': 990,
#  'Bahamas': 991,
#  'considering': 992,
#  'Security': 993,
#  'Arcega': 994,
#  'captives': 995,
#  'lounge': 996,
#  'Ursula': 997,
#  'Hizb-ul-Mujahedeen': 998,
#  'Hasina': 999,
#  'determine': 1000,
#  ...}

# %%
tag2idx
# Out:
# {'I-tim': 0,
#  'B-gpe': 1,
#  'O': 2,
#  'B-geo': 3,
#  'I-per': 4,
#  'B-nat': 5,
#  'I-art': 6,
#  'B-tim': 7,
#  'B-art': 8,
#  'I-org': 9,
#  'B-org': 10,
#  'I-gpe': 11,
#  'I-nat': 12,
#  'I-geo': 13,
#  'B-per': 14,
#  'B-eve': 15,
#  'I-eve': 16}

# %%
plt.figure(figsize = (10, 5))
plt.hist([len(s) for s in sentences], color = 'red', label = 'max_len', bins = 50)
plt.title('MAX LENGTH OF SENTENCE',fontsize = 15)
plt.xlabel('LENGTH', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# - HERE WE CAN SEE THAT THE MAX LENGTH REACHES 60

# %% [markdown]
# ### PADDING WORDS AND TAGS:

# %%
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# %%
max_len = 60
X = [[word2idx[w[0]] for w in s] for s in sentences]
X = pad_sequences(X, maxlen = max_len, padding = 'post', value = num_words - 1)
y = [[tag2idx[t[1]] for t in s] for s in sentences]
y = pad_sequences(y, maxlen = max_len, padding = 'post', value = tag2idx['O'])
y = [to_categorical(i, num_classes = n_tags) for i in y]

# %% [markdown]
# ### SPLITTING THE DATA FOR TRAINING AND TESTING:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 44)

# %%
X_train.shape, X_test.shape
# Out:
# ((38367, 60), (9592, 60))

# %%
print(len(y_train), len(y_test))
# Out:
# 38367 9592

# %% [markdown]
# ### DEFINING BI-LSTM:

# %%
input_dim = num_words + 1
output_dim = max_len
input_length = max_len

# %%
input_dim, output_dim, input_length
# Out:
# (35179, 60, 60)

# %%
from tensorflow.keras import Model, Sequential, Input
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.layers import Bidirectional, TimeDistributed, SpatialDropout1D

# %%
model = Sequential()

model.add(Embedding(input_dim = input_dim, output_dim = output_dim, input_length = input_length))

model.add(SpatialDropout1D(0.1))

model.add(Bidirectional(LSTM(units = 100, recurrent_dropout = 0.1, return_sequences = True)))

model.add(TimeDistributed(Dense(units = n_tags, activation = 'softmax')))

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 60, 60)            2110740
# _________________________________________________________________
# spatial_dropout1d_8 (Spatial (None, 60, 60)            0
# _________________________________________________________________
# bidirectional_8 (Bidirection (None, 60, 200)           128800
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 60, 17)            3417
# =================================================================
# Total params: 2,242,957
# Trainable params: 2,242,957
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

callbacks = EarlyStopping(monitor = 'accuracy', patience = 2, verbose = 1, mode = 'max', restore_best_weights = True)

history = model.fit(X_train, np.array(y_train), batch_size = 32, epochs = 20, callbacks = callbacks, verbose = 1)

#I HAVEN'T INCLUDED VALIDATION SPLIT ABOVE, MAKE SURE YOU ARE INCLUDING IT (OVERFITTING MIGHT BE PREVENTED).
# Out:
# Epoch 1/20
# 1199/1199 [==============================] - 92s 77ms/step - loss: 0.1481 - accuracy: 0.9665
# Epoch 2/20
# 1199/1199 [==============================] - 92s 77ms/step - loss: 0.0413 - accuracy: 0.9878
# Epoch 3/20
# 1199/1199 [==============================] - 92s 77ms/step - loss: 0.0304 - accuracy: 0.9907
# Epoch 4/20
# 1199/1199 [==============================] - 93s 77ms/step - loss: 0.0252 - accuracy: 0.9921
# Epoch 5/20
# 1199/1199 [==============================] - 92s 77ms/step - loss: 0.0216 - accuracy: 0.9930
# Epoch 6/20
# 1199/1199 [==============================] - 94s 78ms/step - loss: 0.0190 - accuracy: 0.9938
# Epoch 7/20
# 1199/1199 [==============================] - 94s 79ms/step - loss: 0.0170 - accuracy: 0.9944
# Epoch 8/20
# 1199/1199 [==============================] - 93s 78ms/step - loss: 0.0152 - accuracy: 0.9950
# Epoch 9/20
# 1199/1199 [==============================] - 94s 78ms/step - loss: 0.0138 - accuracy: 0.9954
# Epoch 10/20
# 1199/1199 [==============================] - 94s 79ms/step - loss: 0.0125 - accuracy: 0.9959
# Epoch 11/20
# 1199/1199 [==============================] - 94s 78ms/step - loss: 0.0112 - accuracy: 0.9963
# Epoch 12/20
# 1199/1199 [==============================] - 94s 78ms/step - loss: 0.0103 - accuracy: 0.9966
# Epoch 13/20
# 1199/1199 [==============================] - 94s 79ms/step - loss: 0.0093 - accuracy: 0.9969
# Epoch 14/20
# 1199/1199 [==============================] - 95s 79ms/step - loss: 0.0086 - accuracy: 0.9971
# Epoch 15/20
# 1199/1199 [==============================] - 94s 78ms/step - loss: 0.0078 - accuracy: 0.9974
# Epoch 16/20
# 1199/1199 [==============================] - 94s 78ms/step - loss: 0.0073 - accuracy: 0.9976
# Epoch 17/20
# 1199/1199 [==============================] - 93s 78ms/step - loss: 0.0067 - accuracy: 0.9978
# Epoch 18/20
# 1199/1199 [==============================] - 93s 78ms/step - loss: 0.0061 - accuracy: 0.9980
# Epoch 19/20
# 1199/1199 [==============================] - 113s 94ms/step - loss: 0.0057 - accuracy: 0.9981
# Epoch 20/20
# 1199/1199 [==============================] - 99s 82ms/step - loss: 0.0053 - accuracy: 0.9982

# %%
model.save('NEW_NER_MODEL.h5')

# %%
model.evaluate(X_test, np.array(y_test))
# Out:
# 300/300 [==============================] - 3s 10ms/step - loss: 0.0738 - accuracy: 0.9865
# [0.07378240674734116, 0.9865043759346008]

# %% [markdown]
# ### LOSS AND ACCURACY OF THE MODEL:

# %%
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=3.0)
plt.plot(history.history['loss'],'g',linewidth=3.0)
plt.legend(['Accuracy', 'Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy and Loss',fontsize=16)
plt.title('Accuracy and Loss Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy and Loss Curves')

# %% [markdown]
# ### TESTING THE NER MODEL:

# %%
i = np.random.randint(0,X_test.shape[0])
p = model.predict(np.array([X_test[i]]))
p = np.argmax(p, axis =-1)
y_true = np.argmax(np.array(y_test), axis =-1)[i]
print("{:15}{:5}\t {} \n".format("Word","True","Pred"))
print("-"*30)
for w,true,pred in zip(X_test[i],y_true,p[0]):
    print("{:15}{}\t{}".format(words[w-1],tags[true],tags[pred]))
# Out:
# Word           True 	 Pred
#
# ------------------------------
# Speaking       O	O
# from           O	O
# his            O	O
# base           O	O
# in             O	O
# Damascus       B-geo	B-geo
# ,              O	O
# Syria          B-geo	B-geo
# ,              O	O
# Khaled         B-per	B-per
# Mashaal        I-per	I-per
# said           O	O
# Saturday       B-tim	B-tim
# Hamas          B-org	B-org
# and            O	O
# the            O	O
# Palestinian    B-gpe	B-gpe
# people         O	O
# will           O	O
# be             O	O
# as             O	O
# effective      O	O
# in             O	O
# politics       O	O
# and            O	O
# reform         O	O
# as             O	O
# in             O	O
# fighting       O	O
# Israel         B-geo	B-geo
# .              O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
# Fitzpatrick    O	O
